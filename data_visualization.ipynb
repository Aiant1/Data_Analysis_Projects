# %% [markdown]
# <a href="https://colab.research.google.com/github/Antikadas1/Data_Analysis_Projects/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Basic plottting using plot function
x1=np.array([0,2,3,4,1,8,9])

y1=np.array([5,4,3,2,2,3,5])
y2=np.array([10,20,50,80,100,500,400])
plt.plot(x1,y1,color="r",linewidth=0.5,marker="o")
plt.plot(x1,y2)
# plt.title("abc")
plt.xlabel("a")
plt.ylabel("b")
plt.ylim(0,100)
plt.ylim(0,100)




# plt.plot(x1,y1)
# plt.title("fig1")
# plt.ylabel("y")
# plt.xlabel("x")
# plt.ylim(0,10)
# plt.xlim(1,10)
# Out:
# (0.0, 100.0)

# %%
#difference betweeb plot and subplot
x=np.linspace(0,20,40)

y1=x**2
y2=x**3
y3=x**4


plt.subplot(2,2,1)
plt.plot(x,y1)

plt.subplot(2,2,2)
plt.plot(x,y2)

plt.subplot(2,2,3)
plt.plot(x,y3)

# %%
#bar/scatter plot
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(5,5),facecolor="green",edgecolor="r")
# # plt.subplot(133)
# plt.bar(names,values)
# plt.subplot(234)
plt.scatter(x,y1,label="x*x")
# plt.scatter(x,y2,label="x*3")

plt.legend(loc=4)

# %%
#more subplots
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(1,3,1)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values,label="abc")
plt.suptitle('Categorical Plotting')
plt.legend()
plt.show()

# %%
#learn about figure object
fig=plt.figure(figsize=(10,5),dpi=100)
axes=fig.add_axes([0.1,0.1,0.9,0.9])
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("fig 2")
axes.plot(x,y1,label="blue")
axes.plot(x,y2,label="yellow")
axes.legend(loc=4) # upper_right loc=1,upper_left loc=0......
# plt.close() #clear memory

# plot inside plot
# axes1=fig.add_axes([0.45,0.45,0.4,0.3])
# axes1.set_xlabel("x1")
# axes1.set_label("y1")
# axes1.set_title("fig 3")
# axes1.plot(x,y1,label="blue")
# axes1.legend(loc=4) # upper_right loc=1,upper_left loc=0......
# # plt.close() #clear memory
# # axes.text(6,1,"message")

# plot inside plot
axes2=fig.add_axes([0.2,0.2,0.2,0.3])
axes2.set_xlabel("x1")
axes2.set_label("y1")
axes2.set_title("fig 3")
axes2.plot(x,y1,label="blue")
axes2.legend(loc=4) # upper_right loc=1,upper_left loc=0......
# plt.close() #clear memory
axes.text(6,1,"message")
# Out:
# Text(6, 1, 'message')

# %%
fig=plt.figure(figsize=(10,5),dpi=100)
axes=fig.add_axes([0.1,0.1,0.9,0.9])
axes.set_xlabel("x")
axes.set_label("y")
axes.set_title("fig 2")
axes.plot(x,y1,label="blue",linewidth=1,markersize=7,marker="v")
axes.plot(x,y2,label="red",linewidth=1,markersize=7,marker="*")

axes.legend(loc=4) # upper_right loc=1,upper_left loc=0......
# plt.close() #clear memory

# %% [markdown]
# # Upto this done

# %%
#save visualization file
fig.savefig("abc.png")

# %%
# visualization with pandas dataFrame
ice_cream_sales=pd.DataFrame({"temp":[30,43,55,43,23,31],"sales":[120,400,600,450,100,300]})
ice_cream_sales
# Out:
#    temp  sales
# 0    30    120
# 1    43    400
# 2    55    600
# 3    43    450
# 4    23    100
# 5    31    300

# %%
x=np.array(ice_cream_sales["temp"])
y=np.array(ice_cream_sales["sales"])

# %%
fig=plt.figure(figsize=(10,5),dpi=100)
axes=fig.add_axes([0.1,0.1,0.9,0.9])
axes.set_xlabel("temp")
axes.set_label("sales")
axes.set_title("fig 2")
axes.plot(x,y,label="blue",linewidth=1,markersize=7,marker="o")
axes.legend(loc=4) # upper_right loc=1,upper_left loc=0......
axes.grid(b=True)
axes.annotate("point",xy=(30,110))
# plt.close() #clear memory
# Out:
# Text(30, 110, 'point')

# %%
#How to write formulas inside a figure
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.9,1])
axes.plot(x,y)

#insteadof text what if we want to put some symbol or equation inside the graph
axes.text(25,500, r'$ \beta \plus \alpha $')
# Out:
# Text(25, 500, '$ \\beta \\plus \\alpha $')

# %%
#histogram
arra1=np.random.randint(1,7,5000)
arra2=np.random.randint(1,7,5000)
print (arra1)
arr3=arra1+arra2

plt.hist(arr3,bins=18,cumulative=True,histtype='step')
# Out:
# [6 1 6 ... 1 2 1]
# (array([ 133.,  402.,  402.,  824.,  824., 1394., 1394., 2099., 2099.,
#         2913., 3596., 3596., 4177., 4177., 4579., 4579., 4860., 5000.]),
#  array([ 2.        ,  2.55555556,  3.11111111,  3.66666667,  4.22222222,
#          4.77777778,  5.33333333,  5.88888889,  6.44444444,  7.        ,
#          7.55555556,  8.11111111,  8.66666667,  9.22222222,  9.77777778,
#         10.33333333, 10.88888889, 11.44444444, 12.        ]),
#  <a list of 1 Patch objects>)

# %%
arra1
